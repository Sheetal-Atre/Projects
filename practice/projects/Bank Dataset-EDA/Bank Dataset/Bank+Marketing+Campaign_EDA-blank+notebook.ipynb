# %% [markdown]
# ## Bank Telemarketing Campaign Case Study.

# %% [markdown]
# In this case study you’ll be learning Exploratory Data Analytics with the help of a case study on "Bank marketing campaign". This will enable you to understand why EDA is a most important step in the process of Machine Learning.

# %% [markdown]
# #### Problem Statement:

# %% [markdown]
#
#
# The bank provides financial services/products such as savings accounts, current accounts, debit cards, etc. to its customers. In order to increase its overall revenue, the bank conducts various marketing campaigns for its financial products such as credit cards, term deposits, loans, etc. These campaigns are intended for the bank’s existing customers. However, the marketing campaigns need to be cost-efficient so that the bank not only increases their overall revenues but also the total profit. You need to apply your knowledge of EDA on the given dataset to analyse the patterns and provide inferences/solutions for the future marketing campaign.
#
# The bank conducted a telemarketing campaign for one of its financial products ‘Term Deposits’ to help foster long-term relationships with existing customers. The dataset contains information about all the customers who were contacted during a particular year to open term deposit accounts.
#
#
# **What is the term Deposit?**
#
# Term deposits also called fixed deposits, are the cash investments made for a specific time period ranging from 1 month to 5 years for predetermined fixed interest rates. The fixed interest rates offered for term deposits are higher than the regular interest rates for savings accounts. The customers receive the total amount (investment plus the interest) at the end of the maturity period. Also, the money can only be withdrawn at the end of the maturity period. Withdrawing money before that will result in an added penalty associated, and the customer will not receive any interest returns.
#
# Your target is to do end to end EDA on this bank telemarketing campaign data set to infer knowledge that where bank has to put more effort to improve it's positive response rate.

# %% [markdown]
# #### Importing the libraries.

# %%
#import the warnings.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Session- 2, Data Cleaning

# %% [markdown]
# ### Segment- 2, Data Types

# %% [markdown]
# There are multiple types of data types available in the data set. some of them are numerical type and some of categorical type. You are required to get the idea about the data types after reading the data frame.
#
# Following are the some of the types of variables:
# - **Numeric data type**: banking dataset: salary, balance, duration and age.
# - **Categorical data type**: banking dataset: education, job, marital, poutcome and month etc.
# - **Ordinal data type**: banking dataset: Age group.
# - **Time and date type**
# - **Coordinates type of data**: latitude and longitude type.

# %% [markdown]
# #### Read in the Data set.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.
inp0= pd.read_csv("bank_marketing_updated_v1.csv")
# Out:
# c:\users\sheetal.atre\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.
inp0= pd.read_csv("bank_marketing_updated_v1.csv")

#Print the head of the data frame.
inp0.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %% [markdown]
# ### Segment- 3, Fixing the Rows and Columns

# %% [markdown]
# Checklist for fixing rows:
# - **Delete summary rows**: Total and Subtotal rows
# - **Delete incorrect rows**: Header row and footer row
# - **Delete extra rows**: Column number, indicators, Blank rows, Page No.
#
# Checklist for fixing columns:
# - **Merge columns for creating unique identifiers**, if needed, for example, merge the columns State and City into the column Full address.
# - **Split columns to get more data**: Split the Address column to get State and City columns to analyse each separately.
# - **Add column names**: Add column names if missing.
# - **Rename columns consistently**: Abbreviations, encoded columns.
# - **Delete columns**: Delete unnecessary columns.
# - **Align misaligned columns**: The data set may have shifted columns, which you need to align correctly.

# %% [markdown]
# #### Read the file without unnecessary headers.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0= inp0.iloc[3:]
    inp0.reset_index()
    

    #Print the head of the data frame.
    print(inp0.head())

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)


    #Print the head of the data frame.
    print(inp0.head())

#skip_header1()
skip_header2()


#inp0.jobedu.value_counts()
#inp0.duration.value_counts()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0= inp0.iloc[3:]
    inp0.reset_index()
    

    #Print the head of the data frame.
    return inp0.head()

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)


    #Print the head of the data frame.
    return inp0.head()

#skip_header1()
df = skip_header2()


#inp0.jobedu.value_counts()
#inp0.duration.value_counts()

#print the head of the data frame.
df.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0= inp0.iloc[3:]
    inp0.reset_index()
    

    #Print the head of the data frame.
    return inp0.head()

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)


    #Print the head of the data frame.
    return inp0.head()

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

#skip_header1()
df = skip_header2()
describe_data(df)

#print the head of the data frame.
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  5 non-null      int64
#  1   age         5 non-null      float64
#  2   salary      5 non-null      int64
#  3   balance     5 non-null      int64
#  4   marital     5 non-null      object
#  5   jobedu      5 non-null      object
#  6   targeted    5 non-null      object
#  7   default     5 non-null      object
#  8   housing     5 non-null      object
#  9   loan        5 non-null      object
#  10  contact     5 non-null      object
#  11  day         5 non-null      int64
#  12  month       5 non-null      object
#  13  duration    5 non-null      object
#  14  campaign    5 non-null      int64
#  15  pdays       5 non-null      int64
#  16  previous    5 non-null      int64
#  17  poutcome    5 non-null      object
#  18  response    5 non-null      object
# ...

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0= inp0.iloc[3:]
    inp0.reset_index()
    

    #Print the head of the data frame.
    return inp0.head()

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)


    #Print the head of the data frame.
    return inp0.head()

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

#skip_header1()
df = skip_header2()
describe_data(df)
convert_datatypes(df)
#print the head of the data frame.
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  5 non-null      int64
#  1   age         5 non-null      float64
#  2   salary      5 non-null      int64
#  3   balance     5 non-null      int64
#  4   marital     5 non-null      object
#  5   jobedu      5 non-null      object
#  6   targeted    5 non-null      object
#  7   default     5 non-null      object
#  8   housing     5 non-null      object
#  9   loan        5 non-null      object
#  10  contact     5 non-null      object
#  11  day         5 non-null      int64
#  12  month       5 non-null      object
#  13  duration    5 non-null      object
#  14  campaign    5 non-null      int64
#  15  pdays       5 non-null      int64
#  16  previous    5 non-null      int64
#  17  poutcome    5 non-null      object
#  18  response    5 non-null      object
# ...

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0= inp0.iloc[3:]
    inp0.reset_index()
    

    #Print the head of the data frame.
    return inp0.head()

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)


    #Print the head of the data frame.
    return inp0.head()

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

#skip_header1()
df = skip_header2()
#describe_data(df)
convert_datatypes(df)
get_avg_age(df)

#print the head of the data frame.
df.head()
# Out:
# ===Average age of customers is :  43.0
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# ...

# %% [markdown]
# ## Fix Rows cols
# Checklist for fixing rows:
#
#     Delete summary rows: Total and Subtotal rows
#
#     Delete incorrect rows: Header row and footer row
#
#     Delete extra rows: Column number, indicators, blank rows, page number
#
#
#
# Checklist for fixing columns:
#
#     if needed, merge columns for creating unique identifiers, for example, merge the columns State and City into the column Full Address.
#      "Rampur" is a city in Uttaranchal, Himachal and Assam. merge city and state col to get unique identifier
#
#     Split columns to get more data: Split the Address column to get State and City columns to analyse each separately.
#     split URL as http://host:port/path
#     split date as DD, MON, YYYY
#     split product heirarchy as prod category
#
#     Add column names: Add column names if missing.
#
#     Rename columns consistently: Abbreviations, encoded columns.
#
#     Delete columns: Delete unnecessary columns.
#
#     Align misaligned columns: The data set may have shifted columns, which you need to align correctly.

# %% [markdown]
# #### Dropping customer id column.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
    inp0.drop("customerid",inplace=True,axis=1)
    
#df = skip_header1()
df = skip_header2()
describe_data(df)
convert_datatypes(df)
get_avg_age(df)
drop_custid_col(df)
print("\n\n====After dropping customerid col===\n\n",describe_data(df))

#print the head of the data frame.
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %% [markdown]
# #### Dividing "jobedu" column into job and education categories.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)
    
def split_jobedu_col(inp0):  
    print("\n\n====Splitting jobedu=====\n")
    print("Null counts ===\n",inp0.jobedu.isnull().value_counts())
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)


    
#df = skip_header1()
df = skip_header2()
#describe_data(df)
convert_datatypes(df)
get_avg_age(df)

drop_custid_col(df)

split_jobedu_col(df)


#print the head of the data frame.
df.head()
# Out:
# ===Average age of customers is :  40.93565090394105
#
#
# ====Splitting jobedu=====
#
# Null counts ===
#  False    45211
# Name: jobedu, dtype: int64
#
#
# ====Splitting month=====
#
# Null counts ===
#  False    45161
# True        50
# Name: month, dtype: int64
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# ...

# %% [markdown]
# ### Segment- 4, Impute/Remove missing values

# %% [markdown]
# Take aways from the lecture on missing values:
#
# - **Set values as missing values**: Identify values that indicate missing data, for example, treat blank strings, "NA", "XX", "999", etc., as missing.
# - **Adding is good, exaggerating is bad**: You should try to get information from reliable external sources as much as possible, but if you can’t, then it is better to retain missing values rather than exaggerating the existing rows/columns.
# - **Delete rows and columns**: Rows can be deleted if the number of missing values is insignificant, as this would not impact the overall analysis results. Columns can be removed if the missing values are quite significant in number.
# - **Fill partial missing values using business judgement**: Such values include missing time zone, century, etc. These values can be identified easily.
#
# Types of missing values:
# - **MCAR**: It stands for Missing completely at random (the reason behind the missing value is not dependent on any other feature).
# - **MAR**: It stands for Missing at random (the reason behind the missing value may be associated with some other features).
# - **MNAR**: It stands for Missing not at random (there is a specific reason behind the missing value).

# %% [markdown]
# #### handling missing values in age column.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)
    
def split_jobedu_col(inp0): 
    #count the missing values in jobedu column.
    print("\n\n====Splitting jobedu=====\n")
    print("Null counts ===\n",inp0.jobedu.isnull().value_counts())
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def split_age_col(inp0):  
    #count the missing values in age column.
    print("\n\n====Splitting age=====\n")
    print("Null counts ===\n",inp0.age.isnull().value_counts())
    
    #pring the shape of dataframe inp0
    print(inp0.shape)
    
    #calculate the percentage of missing values in age column.
    print("====Percent null or not = \n",100 * inp0.age.isnull().value_counts()/inp0.shape[0])
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1= inp0[~inp0.age.isnull()].copy()
    print("===After dropping no of missing age cols : ",inp1.age.isnull().sum())
    
#df = skip_header1()
df = skip_header2()
#describe_data(df)
convert_datatypes(df)
get_avg_age(df)

drop_custid_col(df)

split_jobedu_col(df)

split_age_col(df)
#print the head of the data frame.
df.head()
# Out:
# ===Average age of customers is :  40.93565090394105
#
#
# ====Splitting jobedu=====
#
# Null counts ===
#  False    45211
# Name: jobedu, dtype: int64
#
#
# ====Splitting age=====
#
# Null counts ===
#  False    45191
# True        20
# Name: age, dtype: int64
# (45211, 19)
# ====Percent null or not =
#  False    99.955763
# True      0.044237
# Name: age, dtype: float64
# 0
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# ...

# %% [markdown]
# Drop the records with age missing.

# %% [markdown]
# #### handling missing values in month column

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)
    
def split_jobedu_col(inp0): 
    #count the missing values in jobedu column.
    print("\n\n====Splitting jobedu=====\n")
    print("Null counts ===\n",inp0.jobedu.isnull().value_counts())
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def split_age_col(inp0):  
    #count the missing values in age column.
    print("\n\n====Splitting age=====\n")
    print("Null counts ===\n",inp0.age.isnull().value_counts())
    
    #pring the shape of dataframe inp0
    print(inp0.shape)
    
    #calculate the percentage of missing values in age column.
    print("====Percent null or not = \n",100 * inp0.age.isnull().value_counts()/inp0.shape[0])
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1= inp0[~inp0.age.isnull()].copy()
    print("===After dropping no of missing age cols : ",inp1.age.isnull().sum())

def split_month_col(inp0):  
    #count the missing values in month column in inp1.

    print("\n\n====Splitting month=====\n")
    print("Null counts ===\n",inp0.month.isnull().value_counts())
    
    #print the percentage of each month in the data frame inp1.
    print("\n====Percent null or not = \n",inp0.month.isnull().value_counts(normalize=True))

    #find the mode of month in inp1
    print("\n===Mode is : ",inp0.month.mode())
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(inp0.month.mode()[0],inplace=True)
    
    #let's see the null values in the month column.
    print("\n=====Null counts after replacing with mode ===\n",inp0.month.isnull().value_counts())

    df.month.value_counts()


#df = skip_header1()
df = skip_header2()
#describe_data(df)
convert_datatypes(df)
get_avg_age(df)

drop_custid_col(df)

split_jobedu_col(df)

split_age_col(df)

split_month_col(df)

#print the head of the data frame.
df.head()
# Out:
# ===Average age of customers is :  40.93565090394105
#
#
# ====Splitting jobedu=====
#
# Null counts ===
#  False    45211
# Name: jobedu, dtype: int64
#
#
# ====Splitting age=====
#
# Null counts ===
#  False    45191
# True        20
# Name: age, dtype: int64
# (45211, 19)
# ====Percent null or not =
#  False    99.955763
# True      0.044237
# Name: age, dtype: float64
# ===After dropping no of missing age cols :  0
#
#
# ====Splitting month=====
#
# Null counts ===
#  False    45161
# True        50
# Name: month, dtype: int64
#
# ====Percent null or not =
#  False    0.998894
# True     0.001106
# Name: month, dtype: float64
#
# ===Mode is :  0    may, 2017
# dtype: object
#
# =====Null counts after replacing with mode ===
#  False    45211
# Name: month, dtype: int64
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# ...

# %% [markdown]
# #### handling missing values in response column

# %% [markdown]
# In the bank marketing campaign data set, there are some missing values in the response column. Can you identify the type of missing values?
# MCAR
# The response column has no associations with any other features in the data set. This may be because there is some entry-level error in the data set or there can be some other reasons where the bank does not come to any conclusion regarding whether this particular customer is agreeing or not to invest in term deposits, which obviously has no relation with any other variables in the data set.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)
    
def split_jobedu_col(inp0): 
    #count the missing values in jobedu column.
    print("\n\n====Splitting jobedu=====\n")
    print("Null counts ===\n",inp0.jobedu.isnull().value_counts())
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def split_age_col(inp0):  
    #count the missing values in age column.
    print("\n\n====Splitting age=====\n")
    print("Null counts ===\n",inp0.age.isnull().value_counts())
    
    #pring the shape of dataframe inp0
    print(inp0.shape)
    
    #calculate the percentage of missing values in age column.
    print("====Percent null or not = \n",100 * inp0.age.isnull().value_counts()/inp0.shape[0])
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    print("===After dropping no of missing age cols : ",inp1.age.isnull().sum())
    return inp1
def split_month_col(inp0):  
    #count the missing values in month column in inp1.

    print("\n\n====Splitting month=====\n")
    print("Null counts ===\n",inp0.month.isnull().value_counts())
    
    #print the percentage of each month in the data frame inp1.
    print("\n====Percent null or not = \n",inp0.month.isnull().value_counts(normalize=True))

    #find the mode of month in inp1
    print("\n===Mode is : ",inp0.month.mode())
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(inp0.month.mode()[0],inplace=True)
    
    #let's see the null values in the month column.
    print("\n=====Null counts after replacing with mode ===\n",inp0.month.isnull().value_counts())

    df.month.value_counts()

def drop_response(inp0):
    print("\n\n====dropping response =====\n")
    #count the missing values in response column in inp1.
    print("\n====Null counts of missing response ===\n",inp0.response.isnull().value_counts())

    #calculate the percentage of missing values in response column. 
    print("\n====Null counts response percentage ===\n",100*inp0.response.isnull().value_counts(normalize=True))

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    #calculate the missing values in each column of data frame: inp1.
    print("\n\n====Null counts after dropping missing response ===\n",inp1.response.isnull().value_counts())
    return inp1


#df = skip_header1()
df = skip_header2()
#describe_data(df)
convert_datatypes(df)
get_avg_age(df)

drop_custid_col(df)

split_jobedu_col(df)

inp1 = split_age_col(df)

split_month_col(inp1)

inp2 = drop_response(inp1)


#print the head of the data frame.
#df.head()
#inp1.head()
inp2.head()
# Out:
# ===Average age of customers is :  40.93565090394105
#
#
# ====Splitting jobedu=====
#
# Null counts ===
#  False    45211
# Name: jobedu, dtype: int64
#
#
# ====Splitting age=====
#
# Null counts ===
#  False    45191
# True        20
# Name: age, dtype: int64
# (45211, 19)
# ====Percent null or not =
#  False    99.955763
# True      0.044237
# Name: age, dtype: float64
# ===After dropping no of missing age cols :  0
#
#
# ====Splitting month=====
#
# Null counts ===
#  False    45141
# True        50
# Name: month, dtype: int64
#
# ====Percent null or not =
#  False    0.998894
# True     0.001106
# Name: month, dtype: float64
#
# ===Mode is :  0    may, 2017
# dtype: object
#
# =====Null counts after replacing with mode ===
#  False    45191
# Name: month, dtype: int64
#
#
# ====dropping response =====
#
#
# ====Null counts of missing response ===
#  False    45161
# True        30
# Name: response, dtype: int64
#
# ====Null counts response percentage ===
#  False    99.933615
# ...

# %% [markdown]
# Target variable is better of not imputed.
# - Drop the records with missing values.

# %% [markdown]
# #### handling pdays column.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    print("\n\n===Average age of customers is : ",inp0.age.mean())

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)
    
def split_jobedu_col(inp0): 
    #count the missing values in jobedu column.
    print("\n\n====Splitting jobedu=====\n")
    print("Null counts ===\n",inp0.jobedu.isnull().value_counts())
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def split_age_col(inp0):  
    #count the missing values in age column.
    print("\n\n====Splitting age=====\n")
    print("Null counts ===\n",inp0.age.isnull().value_counts())
    
    #pring the shape of dataframe inp0
    print(inp0.shape)
    
    #calculate the percentage of missing values in age column.
    print("====Percent null or not = \n",100 * inp0.age.isnull().value_counts()/inp0.shape[0])
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    print("===After dropping no of missing age cols : ",inp1.age.isnull().sum())
    return inp1
def split_month_col(inp0):  
    #count the missing values in month column in inp1.

    print("\n\n====Splitting month=====\n")
    print("Null counts ===\n",inp0.month.isnull().value_counts())
    
    #print the percentage of each month in the data frame inp1.
    print("\n====Percent null or not = \n",inp0.month.isnull().value_counts(normalize=True))

    #find the mode of month in inp1
    print("\n===Mode is : ",inp0.month.mode())
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(inp0.month.mode()[0],inplace=True)
    
    #let's see the null values in the month column.
    print("\n=====Null counts after replacing with mode ===\n",inp0.month.isnull().value_counts())

    df.month.value_counts()

def drop_response(inp0):
    print("\n\n====dropping response =====\n")
    #count the missing values in response column in inp1.
    print("\n====Null counts of missing response ===\n",inp0.response.isnull().value_counts())

    #calculate the percentage of missing values in response column. 
    print("\n====Null counts response percentage ===\n",100*inp0.response.isnull().value_counts(normalize=True))

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    #calculate the missing values in each column of data frame: inp1.
    print("\n\n====Null counts after dropping missing response ===\n",inp1.response.isnull().value_counts())
    return inp1

def makenull_pdays(inp0):
    print("\n\n====ignoring pdays(replace -1 to NaN) =====\n")
    #describe the pdays column of inp1.
    print("\n===before cleaning mean pdays is \n",inp0.pdays.describe())
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN
    print("\n===before cleaning mean pdays is \n",inp0.pdays.describe())

#df = skip_header1()
df = skip_header2()
#describe_data(df)
convert_datatypes(df)
get_avg_age(df)

drop_custid_col(df)

split_jobedu_col(df)

inp1 = split_age_col(df)

split_month_col(inp1)

inp2 = drop_response(inp1)

makenull_pdays(inp2)

#print the head of the data frame.
#df.head()
#inp1.head()
inp2.head()
# Out:
# ===Average age of customers is :  40.93565090394105
#
#
# ====Splitting jobedu=====
#
# Null counts ===
#  False    45211
# Name: jobedu, dtype: int64
#
#
# ====Splitting age=====
#
# Null counts ===
#  False    45191
# True        20
# Name: age, dtype: int64
# (45211, 19)
# ====Percent null or not =
#  False    99.955763
# True      0.044237
# Name: age, dtype: float64
# ===After dropping no of missing age cols :  0
#
#
# ====Splitting month=====
#
# Null counts ===
#  False    45141
# True        50
# Name: month, dtype: int64
#
# ====Percent null or not =
#  False    0.998894
# True     0.001106
# Name: month, dtype: float64
#
# ===Mode is :  0    may, 2017
# dtype: object
#
# =====Null counts after replacing with mode ===
#  False    45191
# Name: month, dtype: int64
#
#
# ====dropping response =====
#
#
# ====Null counts of missing response ===
#  False    45161
# True        30
# Name: response, dtype: int64
#
# ====Null counts response percentage ===
#  False    99.933615
# ...

# %% [markdown]
# -1 indicates the missing values.
# Missing value does not always be present as null.
# How to handle it:
#
# Objective is:
# - you should ignore the missing values in the calculations
# - simply make it missing - replace -1 with NaN.
# - all summary statistics- mean, median etc. we will ignore the missing values of pdays.

# %% [markdown]
# ### Segment- 5, Handling Outliers

# %% [markdown]
# Major approaches to the treat outliers:
#
# - **Imputation**
# - **Deletion of outliers**
# - **Binning of values**
# - **Cap the outlier**

# %% [markdown]
# #### Age variable

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def describe_outliers(inp1):
    print("\n\n====Handling Outliers age =====\n")
    #describe the age variable in inp1.
    print(inp1.age.describe())

    #plot the histogram of age variable.
    inp1.age.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(inp1.age)

inp2 = read_and_clean_data()
describe_outliers(inp2)
#print the head of the data frame.
#df.head()
#inp1.head()
inp2.head()
# Out:
# ====Handling Outliers age =====
#
# count    45161.000000
# mean        40.935763
# std         10.618790
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1    NaN         0  unknown       no
# 1  may, 2017  151 sec         1    NaN         0  unknown       no
# ...

# %% [markdown]
# #### Salary variable

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def show_outliers(col):
    #describe the age variable in inp1.
    print(col.describe())

    #plot the histogram of age variable.
    col.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(col)
    
def describe_outliers(inp1):
    #print("\n\n====Handling Outliers age =====\n")
    #show_outliers(inp1.age)
    
    #describe the salary variable of inp1.
    #plot the boxplot of salary variable.
    print("\n\n====Handling Outliers salary =====\n")
    show_outliers(inp1.salary)
    

inp2 = read_and_clean_data()
describe_outliers(inp2)
#print the head of the data frame.
#df.head()
#inp1.head()
inp2.head()
# Out:
# ====Handling Outliers salary =====
#
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
# 3  47.0   20000     1506  married       no      no     yes   no  unknown    5
# 4  33.0       0        1   single       no      no      no   no  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1    NaN         0  unknown       no
# 1  may, 2017  151 sec         1    NaN         0  unknown       no
# ...

# %% [markdown]
# #### Balance variable

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def show_outliers(col):
    #describe the age variable in inp1.
    print(col.describe())

    #plot the histogram of age variable.
    col.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(col)
    plt.show()
    
def describe_outliers(inp1):
    #print("\n\n====Handling Outliers age =====\n")
    #show_outliers(inp1.age)
    
    #describe the salary variable of inp1.
    #plot the boxplot of salary variable.
    #print("\n\n====Handling Outliers salary =====\n")
    #show_outliers(inp1.salary)
    
    #describe the balance variable of inp1.
    #plot the boxplot of balance variable.
    print("\n\n====Handling Outliers balance =====\n")
#     show_outliers(inp1.balance)
    
    #plot the boxplot of balance variable after scaling in 8:2.
#     plt.figure(figsize=[8,2])
#     sns.boxplot(inp1.balance)
#     plt.show()
    
    #print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable
    #If there is a huge difference between the maximum value and the 95th or 99th quantiles, 
    #then there are outliers in the data set.
    print("\nbalance quantiles: (0.5, 0.7, 0.9, 0.95 and 0.99)")
    print(inp1.balance.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.balance.quantile(0.99)
    percentile_95 = inp1.balance.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.balance.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is too high, so possible outliers",diff)
    
    print("\n\n====Handling Outliers salary =====\n")
#     mean_val = inp1.salary.mean()
#     percentile_75 = inp1.salary.quantile(0.75)
#     print("\nFor salary : Mean value is : ",mean_val," and the 75th percentile is : ",percentile_75)
               
    inp1.salary.describe()
    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.98,0.99]))
    sns.boxplot(inp1.salary)
    plt.show()

    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.salary.quantile(0.99)
    percentile_95 = inp1.salary.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.salary.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is 0, so no outliers",diff)
    
          
inp2 = read_and_clean_data()
describe_outliers(inp2)
#print the head of the data frame.
#df.head()
#inp1.head()
# inp2.head()
# Out:
# ====Handling Outliers balance =====
#
#
# balance quantiles: (0.5, 0.7, 0.9, 0.95 and 0.99)
# 0.50      448.0
# 0.70     1126.0
# 0.90     3576.0
# 0.95     5769.0
# 0.99    13173.4
# Name: balance, dtype: float64
#
#
# outliers exist as there is almost these many times variation in 95 and 99 quantile:
#  = 2.2834806725602412
# 95th percentile 5769.0  99th percentile =  13173.40000000003
#
# Max value is :  102127  and the 99th percentile is :  13173.40000000003
# diff between the max balance and the 99th percentile is too high, so possible outliers 88953.59999999998
#
#
# ====Handling Outliers salary =====
#
# 0.50     60000.0
# 0.70     70000.0
# 0.90    100000.0
# 0.98    120000.0
# 0.99    120000.0
# Name: salary, dtype: float64
# 0.50     60000.0
# 0.70     70000.0
# 0.90    100000.0
# 0.95    100000.0
# 0.99    120000.0
# Name: salary, dtype: float64
#
#
# outliers exist as there is almost these many times variation in 95 and 99 quantile:
#  = 1.2
# ...

# %% [markdown]
# Outliers
#
# Consider the following two statements:
#
#     The difference between the maximum value of the balance variable and the 99th percentile is too high.
#
#     The difference between the 99th percentile value and the 95th percentile value of the balance variable is in  the normal range, meaning it is not too high.
#
# Based on the above two statements, choose the correct option which concludes that the balance variable has outliers in it.
#
# Statement 1 is alone sufficient to conclude that balance variables have outliers.
# Inocrrect - Feedback :There may be possibilities that the difference between the maximum value and 99th percentile is high, but there are no outliers in that data.
#
# Both the statements are insufficient to conclude that the balance variable has outliers.
# Inocrrect - You will get some information from sentences to conclude that a particular data set has outliers.
#
# Both the statement are together sufficient to conclude that it has outliers.
# Correct -
# Both the statements are simultaneously required for you to infer from statement 1 that if the maximum value of the variable is far from the 99th percentile, it gives a clear idea that there are outliers in the data set. In addition, from the 2nd statement, you can see that there is no huge difference between the quantile of 95th and 99th.
#
# Any of the statement is alone sufficient to conclude that the balance variable has outliers.

# %% [markdown]
# Outliers
#
# Which of the following methods can be used to identify the outliers (univariate/multivariate) in the dataset?
#
# Box plot can be used to plot the single variable and find its interquartile range and quantiles.
# Correct -
# Box plot gives a clear picture of all the points and visualises the quantiles to infer knowledge about the outliers.
#
# The difference of each point from the mean/median value in the dataset is alone sufficient to identify whether a point is an outlier or not.
#
# Scatter plot can not be used to identify the multivariate outliers.

# %% [markdown]
# Outliers
#
# What is the mean and 75th percentile of the salary variable in bank marketing data set, respectively?
#
# 57004, 60000
#
# 57004, 70000
#
# 70000, 57004
#
# 60000, 57004

# %% [markdown]
# Outliers
#
# After plotting the boxplot, can you write your opinion about the outliers in the salary variable? Are there any outliers in salary?
#
# Ans :
# Once you plot the boxplot, you see that the salary variable does not have any outliers.  All values lies  within the range of 100th percentile always.

# %% [markdown]
# ### Segment- 6, Standardising values

# %% [markdown]
# Checklist for data standardization exercises:
# - **Standardise units**: Ensure all observations under one variable are expressed in a common and consistent unit, e.g., convert lbs to kg, miles/hr to km/hr, etc.
# - **Scale values if required**: Make sure all the observations under one variable have a common scale.
# - **Standardise precision** for better presentation of data, e.g., change 4.5312341 kg to 4.53 kg.
# - **Remove extra characters** such as common prefixes/suffixes, leading/trailing/multiple spaces, etc. These are irrelevant to analysis.
# - **Standardise case**: String variables may take various casing styles, e.g., UPPERCASE, lowercase, Title Case, Sentence case, etc.
# - **Standardise format**: It is important to standardise the format of other elements such as date, name, etce.g., change 23/10/16 to 2016/10/23, “Modi, Narendra” to “Narendra Modi", etc.

# %% [markdown]
# #### Duration variable
#
# You have looked into the bank marketing data set. What is the type of “duration” variable in bank marketing data set? What kind of irregularity this “duration” variable has?
# Duration variable is basically the object type of variable. But it has to be a numeric type. There are data in duration variable in two formats, seconds and minutes. You need to convert in into a single scale either in second or minute.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def show_outliers(col):
    #describe the age variable in inp1.
    print(col.describe())

    #plot the histogram of age variable.
    col.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(col)
    plt.show()
    
def describe_outliers(inp1):
    print("\n\n====Handling Outliers age =====\n")
    show_outliers(inp1.age)
    
    #describe the salary variable of inp1.
    #plot the boxplot of salary variable.
    print("\n\n====Handling Outliers salary =====\n")
    show_outliers(inp1.salary)
    
    #describe the balance variable of inp1.
    #plot the boxplot of balance variable.
    print("\n\n====Handling Outliers balance =====\n")
    show_outliers(inp1.balance)
    
    #plot the boxplot of balance variable after scaling in 8:2.
    plt.figure(figsize=[8,2])
    sns.boxplot(inp1.balance)
    plt.show()
    
    #print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable
    #If there is a huge difference between the maximum value and the 95th or 99th quantiles, 
    #then there are outliers in the data set.
    print("\nbalance quantiles: (0.5, 0.7, 0.9, 0.95 and 0.99)")
    print(inp1.balance.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.balance.quantile(0.99)
    percentile_95 = inp1.balance.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.balance.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is too high, so possible outliers",diff)
    
    print("\n\n====Handling Outliers salary =====\n")
    mean_val = inp1.salary.mean()
    percentile_75 = inp1.salary.quantile(0.75)
    print("\nFor salary : Mean value is : ",mean_val," and the 75th percentile is : ",percentile_75)
               
    inp1.salary.describe()
    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.98,0.99]))
    sns.boxplot(inp1.salary)
    plt.show()

    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.salary.quantile(0.99)
    percentile_95 = inp1.salary.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.salary.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is 0, so no outliers",diff)
    

def standardize_vals(inp2):
    print("\n\n====Standardizing duration =====\n")
    print("\n before converting secs to mins = \n")

    #describe the duration variable of inp1
    print(inp2.duration.describe())
    
    #convert the duration variable into single unit i.e. minutes. and remove the sec or min prefix.    
    inp2["duration"] = inp2.duration.apply(lambda x  : float(x.split(' ')[0]/60)  if x.find('secs')>0 else float(x.split(' ')[0]) )
    
    print("\n after converting secs to mins = \n")
    #describe the duration variable
    print(inp1.duration.describe())

inp2 = read_and_clean_data()
#describe_outliers(inp2)
standardize_vals(inp2)


#print the head of the data frame.
#df.head()
#inp1.head()
# inp2.head()
# Out:
# ====Standardizing duration =====
#
#
#  before converting secs to mins =
#
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object
#
#  after converting secs to mins =
#
# count    45191.000000
# mean        83.267758
# std        184.643508
# min          0.000000
# 25%          2.233333
# 50%          5.000000
# 75%         91.000000
# max       3881.000000
# Name: duration, dtype: float64

# %% [markdown]
# ## Session- 3, Univariate Analysis

# %% [markdown]
# ### Segment- 2, Categorical unordered univariate analysis

# %% [markdown]
# Unordered data do not have the notion of high-low, more-less etc. Example:
# - Type of loan taken by a person = home, personal, auto etc.
# - Organisation of a person = Sales, marketing, HR etc.
# - Job category of persone.
# - Marital status of any one.
#
#
#
# #### Unordered Categorical Variables
#
# Which of the following options are unordered categorical variables? Choose all correct options.
#
# The blood group of any person, such as A, B, O or AB.
# Feedback :
#
# Blood group does not have any order in them. they are just typical category of blood group.
# Correct
#
# Gear of a vehicle: 1st, 2nd, 3rd or 4th gear.
#
# Gender of a person, like male or female.
# Feedback :
#
# Gender is an unordered category, as a person can be male or female; there is no hierarchy in genders.
# Correct
#
# Various stages of cancer.
#
#
#
# #### Student and blue-collar employee
#     # Feedback :
#     # Write a code to find the information about the job variable,
#     # and plot the bar graph of the job variable. Once the code is done, then you will get the correct answer.
#     # inp2.job.value_counts(normalize= True).plot.barh()
#     # plt.show()

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def show_outliers(col):
    #describe the age variable in inp1.
    print(col.describe())

    #plot the histogram of age variable.
    col.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(col)
    plt.show()
    
def describe_outliers(inp1):
    print("\n\n====Handling Outliers age =====\n")
    show_outliers(inp1.age)
    
    #describe the salary variable of inp1.
    #plot the boxplot of salary variable.
    print("\n\n====Handling Outliers salary =====\n")
    show_outliers(inp1.salary)
    
    #describe the balance variable of inp1.
    #plot the boxplot of balance variable.
    print("\n\n====Handling Outliers balance =====\n")
    show_outliers(inp1.balance)
    
    #plot the boxplot of balance variable after scaling in 8:2.
    plt.figure(figsize=[8,2])
    sns.boxplot(inp1.balance)
    plt.show()
    
    #print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable
    #If there is a huge difference between the maximum value and the 95th or 99th quantiles, 
    #then there are outliers in the data set.
    print("\nbalance quantiles: (0.5, 0.7, 0.9, 0.95 and 0.99)")
    print(inp1.balance.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.balance.quantile(0.99)
    percentile_95 = inp1.balance.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.balance.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is too high, so possible outliers",diff)
    
    print("\n\n====Handling Outliers salary =====\n")
    mean_val = inp1.salary.mean()
    percentile_75 = inp1.salary.quantile(0.75)
    print("\nFor salary : Mean value is : ",mean_val," and the 75th percentile is : ",percentile_75)
               
    inp1.salary.describe()
    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.98,0.99]))
    sns.boxplot(inp1.salary)
    plt.show()

    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.salary.quantile(0.99)
    percentile_95 = inp1.salary.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.salary.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is 0, so no outliers",diff)
    

def standardize_vals(inp2):
    print("\n\n====Standardizing duration =====\n")
    print("\n before converting secs to mins = \n")

    #describe the duration variable of inp1
    print(inp2.duration.describe())
    
    #convert the duration variable into single unit i.e. minutes. and remove the sec or min prefix.    
    inp2["duration"] = inp2.duration.apply(lambda x  : float(x.split(' ')[0]/60)  if x.find('secs')>0 else float(x.split(' ')[0]) )
    
    print("\n after converting secs to mins = \n")
    #describe the duration variable
    print(inp2.duration.describe())

def least_most_contacted_jobs():
    df = skip_header2()
    split_jobedu_col(df)
    inp3 = df.groupby(['job'])['pdays'].count()
    #df.head()
    inp3
    
    # Student and blue-collar employee
    # Feedback :
    # Write a code to find the information about the job variable, 
    # and plot the bar graph of the job variable. Once the code is done, then you will get the correct answer.
    # inp2.job.value_counts(normalize= True).plot.barh()
    # plt.show()

    
inp2 = read_and_clean_data()
#describe_outliers(inp2)
standardize_vals(inp2)

least_most_contacted_jobs()

#print the head of the data frame.
#df.head()
#inp1.head()
#inp2.head()
# Out:
# ====Standardizing duration =====
#
#
#  before converting secs to mins =
#
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object
#
#  after converting secs to mins =
#
# count    45161.000000
# mean        83.279022
# std        184.683917
# min          0.000000
# 25%          2.233333
# 50%          5.000000
# 75%         91.000000
# max       3881.000000
# Name: duration, dtype: float64

# %% [markdown]
# #### Marital status

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def show_outliers(col):
    #describe the age variable in inp1.
    print(col.describe())

    #plot the histogram of age variable.
    col.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(col)
    plt.show()
    
def describe_outliers(inp1):
    print("\n\n====Handling Outliers age =====\n")
    show_outliers(inp1.age)
    
    #describe the salary variable of inp1.
    #plot the boxplot of salary variable.
    print("\n\n====Handling Outliers salary =====\n")
    show_outliers(inp1.salary)
    
    #describe the balance variable of inp1.
    #plot the boxplot of balance variable.
    print("\n\n====Handling Outliers balance =====\n")
    show_outliers(inp1.balance)
    
    #plot the boxplot of balance variable after scaling in 8:2.
    plt.figure(figsize=[8,2])
    sns.boxplot(inp1.balance)
    plt.show()
    
    #print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable
    #If there is a huge difference between the maximum value and the 95th or 99th quantiles, 
    #then there are outliers in the data set.
    print("\nbalance quantiles: (0.5, 0.7, 0.9, 0.95 and 0.99)")
    print(inp1.balance.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.balance.quantile(0.99)
    percentile_95 = inp1.balance.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.balance.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is too high, so possible outliers",diff)
    
    print("\n\n====Handling Outliers salary =====\n")
    mean_val = inp1.salary.mean()
    percentile_75 = inp1.salary.quantile(0.75)
    print("\nFor salary : Mean value is : ",mean_val," and the 75th percentile is : ",percentile_75)
               
    inp1.salary.describe()
    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.98,0.99]))
    sns.boxplot(inp1.salary)
    plt.show()

    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.salary.quantile(0.99)
    percentile_95 = inp1.salary.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.salary.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is 0, so no outliers",diff)
    

def standardize_vals(inp2):
    print("\n\n====Standardizing duration =====\n")
    print("\n before converting secs to mins = \n")

    #describe the duration variable of inp1
    print(inp2.duration.describe())
    
    #convert the duration variable into single unit i.e. minutes. and remove the sec or min prefix.    
    inp2["duration"] = inp2.duration.apply(lambda x  : float(x.split(' ')[0]/60)  if x.find('secs')>0 else float(x.split(' ')[0]) )
    
    print("\n after converting secs to mins = \n")
    #describe the duration variable
    print(inp2.duration.describe())

def least_most_contacted_jobs():
    df = skip_header2()
    split_jobedu_col(df)
    inp3 = df.groupby(['job'])['pdays'].count()
    #df.head()
    inp3
    
    # Student and blue-collar employee
    # Feedback :
    # Write a code to find the information about the job variable, 
    # and plot the bar graph of the job variable. Once the code is done, then you will get the correct answer.
    # inp2.job.value_counts(normalize= True).plot.barh()
    # plt.show()

def Categorical_Unordered_Variables(inp2):
    #calculate the percentage of each marital status category.
    #plot the bar graph of percentage marital status categories
    inp2.marital.value_counts(normalize=True).plot.barh()
    plt.show()

    #calculate the percentage of each job status category.
    #plot the bar graph of percentage job categories
    inp2.job.value_counts(normalize=True).plot.barh()
    plt.show()
    
    
inp2 = read_and_clean_data()
#describe_outliers(inp2)
standardize_vals(inp2)

least_most_contacted_jobs()

Categorical_Unordered_Variables(inp2)

#print the head of the data frame.
#df.head()
#inp1.head()
#inp2.head()
# Out:
# ====Standardizing duration =====
#
#
#  before converting secs to mins =
#
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object
#
#  after converting secs to mins =
#
# count    45161.000000
# mean        83.279022
# std        184.683917
# min          0.000000
# 25%          2.233333
# 50%          5.000000
# 75%         91.000000
# max       3881.000000
# Name: duration, dtype: float64

# %% [markdown]
# #### Job

# %% [markdown]
# ### Segment- 3, Categorical ordered univariate analysis

# %% [markdown]
# Ordered variables have some kind of ordering. Some examples of bank marketing dataset are:
# - Age group= <30, 30-40, 40-50 and so on.
# - Month = Jan-Feb-Mar etc.
# - Education = primary, secondary and so on.
#
#
#
# #### Ordered Categorical Variables
#
# You have already worked with ordered categorical variables before - there is a certain order or notion of 'high-low', 'before-after', etc., among the categories. For example, the days of the week (Monday comes before Tuesday), grades of students (A is better than B), number of overs bowled by a bowler (3, 4, 9), etc.
#
# Which of the following are other examples of ordered categorical variables? Choose all correct options.
#
# ##### Dates in a year, e.g., Jan 2, Mar 15, etc.
# Feedback : Dates are ordered - each day comes before or after a certain day.
# Correct
#
# ##### Star rating of a restaurant on Zomato on a scale of 1-5.
# Feedback :A rating of 5 is better than 4, 3, 2, 1. Thus, the ratings follow an order.
# Correct
#
# ##### Type of education board - ICSE, CBSE, Maharashtra board, etc.
#
# ##### Country names
#
#
#
# ### Ordered Categorical Variables
#
# Suppose you are given a data set containing the salary details of the citizens of a tier-2 city. The salaries are not provided in a numerical format but is given qualitatively, for instance, higher salary, above-average salary, average salary, below average salary and no income. Based on this data, how can you determine the standard of living of the citizens of this city? What steps would you follow in order to dissect this information? Write your answer in the comment box below.
#
#
# find percentage of people in each salary category.
# find no of (jobless)people with no income
# find percentage of people with below-average and no income and how they are able to afford the living expenses in the city
# find kind of employment(self employed/jobs) for higher salary, above-average salary categories.
#
#
# First, you should plot the histogram of each category of salary, or you can find the count of each salary group in the data set. Once you have done this, you can predict which category has the highest count, and based on that information, you can predict the standard of living of the people in this city. Suppose you find that the maximum count is for the below-average salary category and the second highest is for the average salary category; thus, you can conclude that the standard of living of the city’s residents is not very high.

# %% [markdown]
# #### Education

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#read the data set of "bank telemarketing campaign" in inp0.

def skip_header1():
    
    #read csv without header
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", header=None)
    
    #header should be third row at index = 2
    header_row=inp0.iloc[2]
    inp0. columns = inp0. iloc[2] 

    #read the file in inp0 without first two rows as it is of no use.
    inp0 = inp0.iloc[3:]
    inp0.reset_index()
    
    return inp0

    #OR
def skip_header2():
    inp0= pd.read_csv("bank_marketing_updated_v1.csv", skiprows=2)

    return inp0

def describe_data(df):    
    #df.jobedu.value_counts()
    #df.duration.value_counts()

    #print the information of variables to check their data types.
    df.info()

def convert_datatypes(inp0):
    #convert the age variable data type from float to integer.
    inp0["age"]= inp0["age"].astype(float)

def get_avg_age(inp0):
    #print the average age of customers.
    avg_age = inp0.age.mean()    
    return avg_age 

def drop_custid_col(inp0):
    #drop the customer id as it is of no use.
#     WHATS USE of inplace= True in this code? Pick the correct option.
#     Use of inplace= True does not return any new data frame but is simply drops the
#                     customerid column in original data frame i.e. inp0.    
# When inplace=False is used, it performs the operation on dataframe and returns a new copy of data.
    inp0.drop("customerid",inplace=True,axis=1)

def blank_row_counts(col):
    #count the missing values in jobedu column.
    #count the missing values in age column.
    #count the missing values in month column in inp1.  
    #count the missing values in response column in inp1.

    blank_rows = col.isnull().value_counts()
    return blank_rows
    
    #OR
#     blank_rows = inp1.age.isnull().sum()
#     return blank_rows;

def percent_blank_rows(col):
    #calculate the percentage of missing values in age column.

    #print the shape of dataframe inp0
#     total_rows = inp0.shape[0]
#     total_cols = inp0.shape[1]
    
#     blank_rows = col.isnull().value_counts()
#     percent_blank_rows = 100*blank_rows/total_rows
#     return percent_blank_rows
    
    #OR
    #print the percentage of each month in the data frame inp1.
    percentage_values = 100 * col.isnull().value_counts(normalize=True)
    return percentage_values


    
def split_jobedu_col(inp0): 
    
    #Extract job in newly created 'job' column from "jobedu" column.
    inp0['job']=inp0.jobedu.apply(lambda x : x.split(",")[0])
    
    #Extract education in newly created 'education' column from "jobedu" column.
    inp0['education']=inp0.jobedu.apply(lambda x : x.split(",")[1])

    #drop the "jobedu" column from the dataframe.
    inp0.drop("jobedu",inplace=True,axis=1)

def drop_age_col(inp0):  
    
    #drop the records with age missing in inp0 and copy in inp1 dataframe.
    inp1 = inp0[~inp0.age.isnull()].copy()
    
    return inp1


def fill_month_with_mode(inp0):      

    #find the mode of month in inp1
    mode_val = inp0.month.mode()[0]
    
    # fill the missing values with mode value of month in inp1.
    inp0.month.fillna(mode_val,inplace=True)
    

def drop_response(inp0):

    #drop the records with response missings in inp1.
    inp1 = inp0[~inp0.response.isnull()].copy()
    
    return inp1

def makenull_pdays(inp0):
    #describe the pdays column of inp1.
    #describe the pdays column with considering the -1 values.
    inp0.loc[inp0.pdays<1,"pdays"] = np.NaN

    
    
def read_and_clean_data():
    #df = skip_header1()
    df = skip_header2()
    #describe_data(df)

    convert_datatypes(df)

    avg_age = get_avg_age(df)
    #print("\n\n===Average age of customers is : ",avg_age)

    drop_custid_col(df)
    #print("\n\n====After dropping customerid col===\n\n")
    #describe_data(df)

    # print("\n\n====Splitting jobedu=====\n")
    # print("\nBefore splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\mblank before dropping = \n",blank_rows)
    # describe_data(df)
    split_jobedu_col(df)
    # print("\nAfter splitting jobedu col : ")
    # blank_rows = blank_row_counts(df.jobedu)
    # print("\nblank after dropping = \n",blank_rows)
    # describe_data(df)

    # print("\n\n====drop missing age rows =====\n")
    # blank_rows = blank_row_counts(df.age)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(df.age)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp1 = drop_age_col(df)
    # blank_rows = blank_row_counts(inp1.age)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.age)
    # print("\nPercent null after dropping = \n",percent_rows)



    # print("\n\n====Splitting month=====\n")
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null before dropping = \n",percent_rows)
    fill_month_with_mode(inp1)
    # blank_rows = blank_row_counts(inp1.month)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.month)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Dropping response =====\n")
    # blank_rows = blank_row_counts(inp1.response)
    # print("\nblank before dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp1.response)
    # print("\nPercent null before dropping = \n",percent_rows)
    inp2 = drop_response(inp1)
    # blank_rows = blank_row_counts(inp2.response)
    # print("\nblank after dropping = \n",blank_rows)
    # percent_rows = percent_blank_rows(inp2.response)
    # print("\nPercent null after dropping = \n",percent_rows)

    # print("\n\n====Ignore missing pdays(replace -1 to NaN) =====\n")
    # print("\n===Before cleaning pdays is \n",inp2.pdays.describe())
    makenull_pdays(inp2)
    # print("\n===after cleaning pdays is \n",inp2.pdays.describe())

    return inp2
    
def show_outliers(col):
    #describe the age variable in inp1.
    print(col.describe())

    #plot the histogram of age variable.
    col.plot.hist()
    plt.title('Age histogram')
    plt.show()
    
    #plot the boxplot of age variable.
    sns.boxplot(col)
    plt.show()
    
def describe_outliers(inp1):
    print("\n\n====Handling Outliers age =====\n")
    show_outliers(inp1.age)
    
    #describe the salary variable of inp1.
    #plot the boxplot of salary variable.
    print("\n\n====Handling Outliers salary =====\n")
    show_outliers(inp1.salary)
    
    #describe the balance variable of inp1.
    #plot the boxplot of balance variable.
    print("\n\n====Handling Outliers balance =====\n")
    show_outliers(inp1.balance)
    
    #plot the boxplot of balance variable after scaling in 8:2.
    plt.figure(figsize=[8,2])
    sns.boxplot(inp1.balance)
    plt.show()
    
    #print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable
    #If there is a huge difference between the maximum value and the 95th or 99th quantiles, 
    #then there are outliers in the data set.
    print("\nbalance quantiles: (0.5, 0.7, 0.9, 0.95 and 0.99)")
    print(inp1.balance.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.balance.quantile(0.99)
    percentile_95 = inp1.balance.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.balance.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is too high, so possible outliers",diff)
    
    print("\n\n====Handling Outliers salary =====\n")
    mean_val = inp1.salary.mean()
    percentile_75 = inp1.salary.quantile(0.75)
    print("\nFor salary : Mean value is : ",mean_val," and the 75th percentile is : ",percentile_75)
               
    inp1.salary.describe()
    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.98,0.99]))
    sns.boxplot(inp1.salary)
    plt.show()

    print(inp1.salary.quantile([0.5, 0.7, 0.9, 0.95,0.99]))
    percentile_99 = inp1.salary.quantile(0.99)
    percentile_95 = inp1.salary.quantile(0.95)
    how_many_times_more = percentile_99/percentile_95
    print("\n\noutliers exist as there is almost these many times variation in 95 and 99 quantile:\n =",
          how_many_times_more,
          "\n95th percentile",percentile_95," 99th percentile = ",percentile_99)

    max_val = inp1.salary.max()
    print("\nMax value is : ",max_val," and the 99th percentile is : ",percentile_99)
    diff = max_val - percentile_99
    print("diff between the max balance and the 99th percentile is 0, so no outliers",diff)
    

def standardize_vals(inp2):
#     print("\n\n====Standardizing duration =====\n")
#     print("\n before converting secs to mins = \n")

    #describe the duration variable of inp1
#     print(inp2.duration.describe())
    
    #convert the duration variable into single unit i.e. minutes. and remove the sec or min prefix.    
    inp2["duration"] = inp2.duration.apply(lambda x  : float(x.split(' ')[0]/60)  if x.find('secs')>0 else float(x.split(' ')[0]) )
    
#     print("\n after converting secs to mins = \n")
    #describe the duration variable
#     print(inp2.duration.describe())

def least_most_contacted_jobs():
    df = skip_header2()
    split_jobedu_col(df)
    inp3 = df.groupby(['job'])['pdays'].count()
    #df.head()
    inp3
    
    # Student and blue-collar employee
    # Feedback :
    # Write a code to find the information about the job variable, 
    # and plot the bar graph of the job variable. Once the code is done, then you will get the correct answer.
    # inp2.job.value_counts(normalize= True).plot.barh()
    # plt.show()

def Categorical_Unordered_Variables(inp2):
    #calculate the percentage of each marital status category.
    #plot the bar graph of percentage marital status categories
    inp2.marital.value_counts(normalize=True).plot.barh()
    plt.show()

    #calculate the percentage of each job status category.
    #plot the bar graph of percentage job categories
    inp2.job.value_counts(normalize=True).plot.barh()
    plt.show()
    
def Categorical_Ordered_Variables(inp2):
    #calculate the percentage of each education category.
    #plot the pie chart of education categories
    inp2.education.value_counts(normalize=True).plot.barh()
    plt.show()

    #calculate the percentage of each poutcome category.
    inp2.poutcome.value_counts(normalize=True).plot.barh()
    plt.show()
    inp2[~(inp2.poutcome == 'unknown')].poutcome.value_counts(normalize=True).plot.barh()

    plt.show()

    #### Response the target variable 
    #calculate the percentage of each response category.
    #plot the pie chart of response categories
    inp2.response.value_counts(normalize=True).plot.pie()
    plt.show()

inp2 = read_and_clean_data()
#describe_outliers(inp2)
standardize_vals(inp2)

least_most_contacted_jobs()

#Categorical_Unordered_Variables(inp2)

#Categorical_Ordered_Variables(inp2)


#print the head of the data frame.
#df.head()
#inp1.head()
#inp2.head()

# %% [markdown]
# #### poutcome

# %% [markdown]
# #### Numeric and Ordered Categorical Variables
#
#
#
# Anand mentioned that you can treat numeric variables as ordered categorical variables. For analysis, you can deliberately convert the numeric variables into ordered categorical; for example, if you have the incomes of a few thousand people, which range from $5,000 to $1,00,000, then you can categorise them into bins such as [5000, 10000], [10000,15000] and [15000, 20000].
#
# This is called 'binning'.
#
# Now, which of the following variables can be binned into ordered categorical variables? Mark all correct options.
#
# The temperature for a city over a certain period of time.
# Feedback :
#
# You can bin the temperatures as [0, 10 degrees], [10, 20 degrees], etc.
# Correct
#
# The revenue generated by a company per day.
# Feedback :
#
# This can also be binned, e.g., [0, 10k], [10k, 20k], etc.
# Correct
#
# Randomly generated unique customer IDs, such as 17913, 1282, 2380, etc.
# Feedback :
#
# This is a random number and these are customer IDs; hence, it cannot be binned.
# Incorrect
#
#
#
#
# Which Metric to Use
#
#
#
# Consider the example Anand is discussing in the video: There is a group of middle-class IT employees and Bill Gates in a room. Now, which metric would you choose if you wanted to get a rough idea of the income of a typical IT employee?
#
# Mean
#
# Median
# Feedback :
#
# The average, calculated taking Bill Gates’ income into account, would be an overwhelmingly large number far from the income of any other IT employee in the room. On the other hand, the median will not consider Bill Gates’ income and would be more representative.
#
#
# #### Note :
# Typical employee - median - central employee - arrange all emps in a line, pick central as typical. so all outliers are ignored. middle person is representative of the group. people dont normally go for this but its v effective.
#
#
# Mean -look carefully - whether it has been used by default without thinking - it should be representative of complete dataset
#
# eg bill gates salary must be considered for tax calculating. so tax is a func of (mean)
#
# but bill gates is not typical representative of the population. to find typical salary of the group consider median
#
#
# ### Quantile
# A quantile defines a particular part of a data set, i.e. a quantile determines how many values in a distribution are above or below a certain limit. Special quantiles are the quartile (quarter), the quintile (fifth) and percentiles (hundredth).
#
# Statistics
#
# The table below shows the marks scored (out of 100) in a course exam:
#
# Quantiles	Min	10%	25%	50%	75%	90%	Max
# Final Marks	10	48	55	66	78	87	93
#
# Which of the following statements is FALSE?
#
# About 1/4 of the class received a score of 55 or less.
#
# About 3/4 of the class received a score of 78 or less.
#
# About 50% of the class received grades between 55 and 78.
#
# The median of class marks is more than 66.
# Feedback :
#
# Median is simply the 50th percentile of the data; hence, the median of the data is 66, and not more than 66.
# Correct
#
# About 1/30 of the class received a score of 48 or less.
# Feedback :
#
# About 10% of the class received a score of 48 or less.
#
#
# ### Univariate Analysis
#
# Univariate Analysis
#
# Which of the following values should be affected by outliers:
#
# Mean; median may also be slightly affected
# Feedback :
#
# Mean is greatly affected by outliers, and median may be slightly affected.
#
# CorrectYou missed this!
#
# Mode; median may also be slightly affected
#
# Standard deviation and variance
# Feedback :
#
# Since mean is affected by outliers, variance and standard deviation will also be affected by outliers.
#
# Correct
#
# Variance and mode
#
#
# The mean is the sum of all the values divided by the number of values. It can be strongly affected by outliers. The median is the middle value in a data set. It is not affected by outliers.
#
#
# Outlier Affect on variance, and standard deviation of a data distribution. In a data distribution, with extreme outliers, the distribution is skewed in the direction of the outliers which makes it difficult to analyze the data.
#
# Standard deviation is never negative. Standard deviation is sensitive to outliers. A single outlier can raise the standard deviation and in turn, distort the picture of spread. For data with approximately the same mean, the greater the spread, the greater the standard deviation.
#
#
# ### Univariate Analysis
#
# Take a look at the graph below, which represents the numeric variable according to its frequencies, and choose the option that shows the correct order of the mean, median and mode.
#
#
# Median > Mode > Mean
#
# Median > Mean > Mode
#
# Mode > Median > Mean
#
# Mean > Median> Mode
#
# <br/>Feedback :Mean > Median> Mode
#
# The mode value is the lowest among the three parameters because this value has the highest frequency. Median should lie between the mean and mode.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Take a look at the graph below, which represents the numeric variable
# according to its frequencies, and choose the option that
# shows the correct order of the mean, median and mode.
# 1,1,2,2,2,3,3,4,5,

df = pd.DataFrame([6,5,4,3,3,2,2,2,1,1])
df.columns = ["data"]
rows=[i for i in range(1,11) ]
df["rows"]=rows
print(df)

print("Mean = 2.9 > ", df.mean()," ,Median - 2.5 > ", df.median()," , Mode 2.0 : ", df.data.mode())
sns.lineplot(data=df,x="data",y="rows")
plt.show()
# Out:
#    data  rows
# 0     6     1
# 1     5     2
# 2     4     3
# 3     3     4
# 4     3     5
# 5     2     6
# 6     2     7
# 7     2     8
# 8     1     9
# 9     1    10
# Mean = 2.9 >  data    2.9
# rows    5.5
# dtype: float64  ,Median - 2.5 >  data    2.5
# rows    5.5
# dtype: float64  , Mode 2.0 :  0    2
# dtype: int64

# %% [markdown]
# #### Response the target variable

# %% [markdown]
# ## Statistics
#
# The table below shows the marks scored (out of 100) in a course exam:
#
# Quantiles	Min	10%	25%	50%	75%	90%	Max
# Final Marks	10	48	55	66	78	87	93
#
# Which of the following statements is FALSE?
#
# About 1/4 of the class received a score of 55 or less.
#
# About 3/4 of the class received a score of 78 or less.
#
# About 50% of the class received grades between 55 and 78.
#
# The median of class marks is more than 66.
#
# About 1/30 of the class received a score of 48 or less.

# %% [markdown]
# ## Session- 4, Bivariate and Multivariate Analysis

# %% [markdown]
# ### Segment-2, Numeric- numeric analysis

# %% [markdown]
# There are three ways to analyse the numeric- numeric data types simultaneously.
# - **Scatter plot**: describes the pattern that how one variable is varying with other variable.
# - **Correlation matrix**: to describe the linearity of two numeric variables.
# - **Pair plot**: group of scatter plots of all numeric variables in the data frame.

# %%
#plot the scatter plot of balance and salary variable in inp1

# %%
#plot the scatter plot of balance and age variable in inp1

# %%
#plot the pair plot of salary, balance and age in inp1 dataframe.

# %% [markdown]
# #### Correlation heat map

# %%
#plot the correlation matrix of salary, balance and age in inp1 dataframe.

# %% [markdown]
# ### Segment- 4, Numerical categorical variable

# %% [markdown]
# #### Salary vs response

# %%
#groupby the response to find the mean of the salary with response no & yes seperatly.

# %%
#groupby the response to find the median of the salary with response no & yes seperatly.

# %%
#plot the box plot of salary for yes & no responses.

# %% [markdown]
# #### Balance vs response

# %%
#plot the box plot of balance for yes & no responses.

# %%
#groupby the response to find the mean of the balance with response no & yes seperatly.

# %%
#groupby the response to find the median of the balance with response no & yes seperatly.

# %% [markdown]
# ##### 75th percentile

# %%
#function to find the 75th percentile.
def p75(x):
    return np.quantile(x, 0.75)

# %%
#calculate the mean, median and 75th percentile of balance with response

# %%
#plot the bar graph of balance's mean an median with response.

# %% [markdown]
# #### Education vs salary

# %%
#groupby the education to find the mean of the salary education category.

# %%
#groupby the education to find the median of the salary for each education category.

# %% [markdown]
# #### Job vs salary

# %%
#groupby the job to find the mean of the salary for each job category.

# %% [markdown]
# ### Segment- 5, Categorical categorical variable

# %%
#create response_flag of numerical data type where response "yes"= 1, "no"= 0

# %% [markdown]
# #### Education vs response rate

# %%
#calculate the mean of response_flag with different education categories.

# %% [markdown]
# #### Marital vs response rate

# %%
#calculate the mean of response_flag with different marital status categories.

# %%
#plot the bar graph of marital status with average value of response_flag

# %% [markdown]
# #### Loans vs response rate

# %%
#plot the bar graph of personal loan status with average value of response_flag

# %% [markdown]
# #### Housing loans vs response rate

# %%
#plot the bar graph of housing loan status with average value of response_flag

# %% [markdown]
# #### Age vs response

# %%
#plot the boxplot of age with response_flag

# %% [markdown]
# ##### making buckets from age columns

# %%
#create the buckets of <30, 30-40, 40-50 50-60 and 60+ from age column.

# %%
#plot the percentage of each buckets and average values of response_flag in each buckets. plot in subplots.

# %%
#plot the bar graph of job categories with response_flag mean value.

# %% [markdown]
# ### Segment-6, Multivariate analysis

# %% [markdown]
# #### Education vs marital vs response

# %%
#create heat map of education vs marital vs response_flag

# %% [markdown]
# #### Job vs marital vs response

# %%
#create the heat map of Job vs marital vs response_flag.

# %% [markdown]
# #### Education vs poutcome vs response

# %%
#create the heat map of education vs poutcome vs response_flag.
